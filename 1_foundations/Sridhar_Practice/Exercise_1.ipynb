# %%
from dotenv import load_dotenv
import os   
load_dotenv(override=True)

my_open_Api_key = os.getenv("OPENAI_API_KEY")

# print(my_open_Api_key)

from openai import OpenAI

client_sridharKidambi = OpenAI(api_key=my_open_Api_key)

messages= [
      {
        "role": "developer",
        "content": "Select an Industry which has a high AI potential for deployment"
      }
    ]
response = client_sridharKidambi.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

 
content_frame="Explore one detailed challenges in the Industry AI adoption "+response.choices[0].message.content
messages=""
messages= [
      {
        "role": "developer",
        "content": content_frame
      }
    ]


response = client_sridharKidambi.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)


content_frame="Provide ways to address the challenge posed by the "+response.choices[0].message.content
messages=""
messages= [
      {
        "role": "developer",
        "content": content_frame
      }
    ]


response = client_sridharKidambi.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Addressing the integration of AI systems into existing clinical workflows in the healthcare industry requires a multifaceted approach that tackles the challenges head-on. Below are strategies that can help healthcare organizations successfully integrate AI technologies:
#
# ### Strategies to Address Integration Challenges
#
# 1. **Change Management Initiatives**:
#    - Implement change management strategies to reduce resistance, including engaging healthcare professionals early in the AI adoption process, demonstrating AI benefits, and addressing concerns about job displacement. Involve staff in pilot projects to foster a sense of ownership and acceptance.
#
# 2. **Interoperability Standards**:
# ...
